# %% [markdown]
# <a href="https://colab.research.google.com/github/talapantitejaswini/Fmml/blob/main/mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:38:34--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   240MB/s    in 0.3s
#
# 2025-03-16 06:38:36 (240 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 38836  1604.00999v2  Since the launch of the Microsoft Kinect, scor...    cs
# 7842   1803.07819v1  Generative Adversarial Networks (GANs) are a c...  stat
# 10342   1209.4951v3  Conventional multiclass conditional probabilit...  stat
# 29663  1710.01115v3  Myocardial Infarction is one of the leading ca...    cs
# 25442  1509.01624v1  In 3D image/video acquisition, different views...    cs
# ...             ...                                                ...   ...
# 22871  1709.07175v1  Stochastic principal component analysis (SPCA)...  stat
# 21781  1505.00428v2  Infinite Hidden Markov Models (iHMM's) are an ...  stat
# 22038   1312.7604v2  Archetypal analysis represents a set of observ...  stat
# 12289  1711.04015v1  We propose a new learning to rank algorithm, n...  stat
# 23008  1801.09185v1  Marketing analytics is a diverse field, with b...  stat
#
#                                                    title  year  \
# 38836            RGBD Datasets: Past, Present and Future  2016
# 7842                 Some Theoretical Properties of GANs  2018
# 10342  An efficient model-free estimation of multicla...  2012
# 29663  Detection of Inferior Myocardial Infarction us...  2017
# 25442  Chebyshev and Conjugate Gradient Filters for G...  2015
# ...                                                  ...   ...
# 22871       Lazy stochastic principal component analysis  2017
# 21781  A Linear-Time Particle Gibbs Sampler for Infin...  2015
# 22038                  Probabilistic Archetypal Analysis  2013
# 12289  WMRB: Learning to Rank in a Scalable Batch Tra...  2017
# 23008  Marketing Analytics: Methods, Practice, Implem...  2018
#
#                                                 keywords
# 38836  [microsoft, propelled, reconstruction, recogni...
# 7842   [generative, adversarial, generative, algorith...
# 10342  [conventional, multiclass, conditional, probab...
# 29663  [myocardial, infarction, worldwide, convolutio...
# 25442  [imagevideo, acquisition, different, enhanceme...
# ...                                                  ...
# 22871  [stochastic, principal, component, dimensional...
# 21781  [attractive, nonparametric, generalization, cl...
# 22038  [archetypal, represents, observations, combina...
# 12289  [algorithm, approximate, estimator, efficient,...
# 23008  [marketing, analytics, researchers, practition...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 38836    [microsoft, propelled, reconstruction, recogni...
# 7842     [generative, adversarial, generative, algorith...
# 10342    [conventional, multiclass, conditional, probab...
# 29663    [myocardial, infarction, worldwide, convolutio...
# 25442    [imagevideo, acquisition, different, enhanceme...
#                                ...
# 20512    [recognition, formulated, classical, heuristic...
# 9638     [particular, framework, reconstruction, coeffi...
# 4680     [developed, knowledge, embedding, assumption, ...
# 22865    [introduces, generalised, comprising, stochast...
# 10646    [structure, intracranial, electroencephalogram...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8748 words.
# Out of those 4570 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9b30e1ac-3a00-49ca-9fe2-2e78f597ce76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b30e1ac-3a00-49ca-9fe2-2e78f597ce76")) {                    Plotly.newPlot(                        "9b30e1ac-3a00-49ca-9fe2-2e78f597ce76",                        [{"x":["categories","reconstruction","synthetic","recognition","currently","researchers","appropriate","reconstructions","microsoft","reviewing","identification","information","extracting","semantics","directions","succeeded","underexplored","estimation","principle","particular","illustrated","connection","generative","underlying","optimality","estimated","properties","theoretical","distribution","mathematical","arguments","algorithms","optimizing","analyzing","simulated","especially","fundamental","generators","discriminator","approximation","objective","divergence","characteristics","approximate","understanding","adversarial","statistical","discriminators","converted","demonstrate","restrictive","cumulative","difference","corresponding","functions","relatively","efficient","exponentially","assumption","regression","computation","competitive","distributional","conventional","formulated","probability","discriminate","numerical","competitors","conditional","specifically","multiclass","myocardial","performance","evaluated","euclidean","specificity","sensitivity","capability","infarction","convolutional","separability","geometric","discriminating","comprehend","detection","worldwide","benchmark","architecture","generalization","extracted","differentiates","projection","previously","improvement","conjugate","different","imagevideo","subjectively","chebyshev","generalizes","computing","filtering","perspectives","polynomial","algorithm","acquisition","auxiliary","laplacian","technique","denoising","polynomials","enhancement","dimensional","iterations","framework","simulations","including","engineered","remarkable","optimization","derivative","parameter","exploitation","exploration","benchmarks","optimizers","recurrent","favourably","efficiently","objectives","invariant","continuous","dynamical","correlation","treatment","frequency","represents","counterfactual","significant","multivariate","continuously","observational","challenge","estimating","interventions","structure","processes","potential","reasoning","challenging","traditional","environment","experiments","reinforcement","backwards","introduce","maximizes","annotations","available","resulting","primitives","transfers","collected","annotation","intensive","pixelwise","baselines","particularly","unfortunately","segmentation","comparison","frequentist","practical","uhlenbeck","procedure","perspective","stochastic","asymptotically","potentially","classical","intuitive","comparable","requiring","inference","sequences","dependency","procedures","investigated","successfully","therefore","synthesized","applicability","synthesis","boundaries","structures","conducted","variation","intensity","standardized"],"y":[86,90,140,369,47,77,88,13,15,4,105,725,62,104,49,3,3,197,59,282,10,31,114,112,23,61,200,127,208,69,21,594,49,43,57,127,84,11,15,133,172,24,78,123,155,110,152,3,5,557,7,12,48,126,216,65,407,21,61,116,143,96,22,91,38,166,17,68,9,96,180,9,1,902,149,35,9,29,48,1,352,9,71,7,6,327,6,210,233,99,126,3,51,98,143,13,730,3,5,1,37,113,79,17,65,837,39,28,23,260,47,5,33,178,29,527,38,245,13,27,298,8,139,23,49,100,6,137,2,146,27,66,90,16,75,34,53,45,5,222,15,21,5,155,65,5,379,102,164,132,276,158,109,629,109,3,332,10,74,292,149,13,5,84,49,23,6,57,86,38,178,133,1,123,1,95,65,128,10,51,89,46,88,44,226,101,56,47,36,98,139,17,34,51,37,130,81,56,34,8],"type":"bar"},{"x":["categories","reconstruction","synthetic","recognition","currently","researc ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4570,), (4570, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.341991341991342);'>Understanding</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.37869822485207105);'>representations</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measuring</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>equivariance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <br/><br/><span style=''>Despite</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.37869822485207105);'>representations</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>histograms</span> <span style=''>of</span> <span style=''>oriented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>and</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(CNN)</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3981042654028436);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.341991341991342);'>understanding</span> <span style=''>of</span> <span style=''>them</span> <span style=''>remains</span> <span style=''>limited</span> <span style=''>Aiming</span> <span style=''>at</span> <span style=''>filling</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>three</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.37869822485207105);'>representations</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>equivariance</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>invariance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Equivariance</span> <span style=''>studies</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>image</span> <span style=''>are</span> <span style=''>encoded</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4057142857142857);'>representation</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>invariance</span> <span style=''>being</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>where</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformation</span> <span style=''>has</span> <span style=''>no</span> <span style=''>effect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equivalence</span> <span style=''>studies</span> <span style=''>whether</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.37869822485207105);'>representations</span> <span style=''>for</span> <span style=''>example</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.32848043676069155);'>different</span> <span style=''>parametrisations</span> <span style=''>of</span> <span style=''>a</span> <span style=''>CNN</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>same</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Intrinsic</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>on</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>domains</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(in</span> <span style=''>GPs)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>with</span> <span style=''>a</span> <span style=''>primary</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>domains</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irregular</span> <span style=''>shaped</span> <span style=''>spaces</span> <span style=''>arising</span> <span style=''>as</span> <span style=''>subsets</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submanifolds</span> <span style=''>of</span> <span style=''>R</span> <span style=''>R2</span> <span style=''>R3</span> <span style=''>and</span> <span style=''>beyond</span> <span style=''>For</span> <span style=''>example</span> <span style=''>in</span> <span style=''>GPs</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodate</span> <span style=''>spatial</span> <span style=''>domains</span> <span style=''>arising</span> <span style=''>as</span> <span style=''>complex</span> <span style=''>subsets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>in</span> <span style=''>GPs</span> <span style=''>respect</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>complex</span> <span style=''>boundary</span> <span style=''>or</span> <span style=''>interior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spaces</span> <span style=''>The</span> <span style=''>key</span> <span style=''>novelty</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>utilise</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>heat</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>density</span> <span style=''>of</span> <span style=''>Brownian</span> <span style=''>motion</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>valid</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>CNNs</span> <span style=''>are</span> <span style=''>Globally</span> <span style=''>Optimal</span> <span style=''>Given</span> <span style=''>Multi</span> <span style=''>Layer</span> <span style=''>Support</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3976470588235294);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>(SGD)</span> <span style=''>is</span> <span style=''>the</span> <span style=''>central</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>workhorse</span> <span style=''>for</span> <span style=''>training</span> <span style=''>modern</span> <span style=''>CNNs</span> <span style=''>Although</span> <span style=''>giving</span> <span style='background-color:rgba(0, 255, 0, 0.35714285714285715);'>impressive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>slow</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>strategy</span> <span style=''>for</span> <span style=''>training</span> <span style=''>a</span> <span style=''>CNN</span> <span style=''>using</span> <span style=''>an</span> <span style=''>alternation</span> <span style=''>strategy</span> <span style=''>that</span> <span style=''>offers</span> <span style='background-color:rgba(0, 255, 0, 0.4864864864864864);'>substantial</span> <span style=''>speedups</span> <span style=''>during</span> <span style=''>training</span> <span style=''>We</span> <span style=''>make</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributions</span> <span style=''>(i)</span> <span style=''>replace</span> <span style=''>the</span> <span style=''>ReLU</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>linearity</span> <span style=''>within</span> <span style=''>a</span> <span style=''>CNN</span> <span style=''>with</span> <span style=''>positive</span> <span style=''>hard</span> <span style='background-color:rgba(255, 0, 0, 0.4901960784313726);'>thresholding</span> <span style=''>(ii)</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>reinterpret</span> <span style=''>this</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>linearity</span> <span style=''>as</span> <span style=''>a</span> <span style=''>binary</span> <span style=''>state</span> <span style=''>vector</span> <span style=''>making</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>CNN</span> <span style=''>linear</span> <span style=''>if</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>layer</span> <span style=''>support</span> <span style=''>is</span> <span style=''>known</span> <span style=''>and</span> <span style=''>(iii)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>a</span> <span style=''>global</span> <span style=''>optima</span> <span style=''>to</span> <span style=''>the</span> <span style=''>CNN</span> <span style=''>can</span> <span style=''>be</span> <span style=''>found</span> <span style=''>through</span> <span style=''>local</span> <span style=''>descent</span> <span style=''>We</span> <span style=''>then</span> <span style=''>employ</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>alternation</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>by</span> <span style=''>Deep</span> <span style=''>Nearest</span> <span style=''>Neighbor</span> <span style=''>Descent</span> <span style=''>(D</span> <span style=''>NND)</span> <span style=''>A</span> <span style=''>Density</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Insensitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>Method</span> <br/><br/><span style=''>Most</span> <span style=''>density</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>largely</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>how</span> <span style=''>well</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>density</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>However</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>itself</span> <span style=''>is</span> <span style=''>also</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determination</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bandwidth</span> <span style=''>A</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bandwidth</span> <span style=''>could</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style=''>over</span> <span style=''>smoothed</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>density</span> <span style=''>peaks</span> <span style=''>could</span> <span style=''>be</span> <span style=''>less</span> <span style=''>than</span> <span style=''>the</span> <span style=''>true</span> <span style=''>clusters</span> <span style=''>while</span> <span style=''>a</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bandwidth</span> <span style=''>could</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style=''>under</span> <span style=''>smoothed</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>which</span> <span style=''>spurious</span> <span style=''>density</span> <span style=''>peaks</span> <span style=''>or</span> <span style=''>called</span> <span style=''>the</span> <span style=''>ripple</span> <span style=''>noise</span> <span style=''>would</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>density</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>density</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>method</span> <span style=''>called</span> <span style=''>the</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.064352856109906)
# 	representation (0.1334056399132321)
# 	knowledge (0.13412870571221983)
# 	experimental (0.13955169920462762)
# 	processing (0.1153289949385394)
# 	detection (0.11822125813449023)
# 	different (0.26391901663051337)
# 	convolutional (0.1272595806218366)
# 	information (0.2621113521330441)
# 	recognition (0.1334056399132321)
#
# Some Statistics words are:
# 	convergence (0.12094395280235988)
# 	estimation (0.16470009832841692)
# 	variables (0.1376597836774828)
# 	statistical (0.15388397246804325)
# 	theoretical (0.14503441494591937)
# 	stochastic (0.14601769911504425)
# 	inference (0.19321533923303835)
# 	distribution (0.18928220255653885)
# 	dimensional (0.17895771878072764)
# 	regression (0.18534906588003933)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c8c37d3a-0575-4eee-ac10-fb6511f62586" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8c37d3a-0575-4eee-ac10-fb6511f62586")) {                    Plotly.newPlot(                        "c8c37d3a-0575-4eee-ac10-fb6511f62586",                        [{"x":["categories","reconstruction","synthetic","recognition","currently","researchers","appropriate","reconstructions","microsoft","reviewing","identification","information","extracting","semantics","directions","succeeded","underexplored","estimation","principle","particular","illustrated","connection","generative","underlying","optimality","estimated","properties","theoretical","distribution","mathematical","arguments","algorithms","optimizing","analyzing","simulated","especially","fundamental","generators","discriminator","approximation","objective","divergence","characteristics","approximate","understanding","adversarial","statistical","discriminators","converted","demonstrate","restrictive","cumulative","difference","corresponding","functions","relatively","efficient","exponentially","assumption","regression","computation","competitive","distributional","conventional","formulated","probability","discriminate","numerical","competitors","conditional","specifically","multiclass","myocardial","performance","evaluated","euclidean","specificity","sensitivity","capability","infarction","convolutional","separability","geometric","discriminating","comprehend","detection","worldwide","benchmark","architecture","generalization","extracted","differentiates","projection","previously","improvement","conjugate","different","imagevideo","subjectively","chebyshev","generalizes","computing","filtering","perspectives","polynomial","algorithm","acquisition","auxiliary","laplacian","technique","denoising","polynomials","enhancement","dimensional","iterations","framework","simulations","including","engineered","remarkable","optimization","derivative","parameter","exploitation","exploration","benchmarks","optimizers","recurrent","favourably","efficiently","objectives","invariant","continuous","dynamical","correlation","treatment","frequency","represents","counterfactual","significant","multivariate","continuously","observational","challenge","estimating","interventions","structure","processes","potential","reasoning","challenging","traditional","environment","experiments","reinforcement","backwards","introduce","maximizes","annotations","available","resulting","primitives","transfers","collected","annotation","intensive","pixelwise","baselines","particularly","unfortunately","segmentation","comparison","frequentist","practical","uhlenbeck","procedure","perspective","stochastic","asymptotically","potentially","classical","intuitive","comparable","requiring","inference","sequences","dependency","procedures","investigated","successfully","therefore","synthesized","applicability","synthesis","boundaries","structures","conducted","variation","intensity","standardized","consistency","impressively","effectiveness","presumably","scenarios","generates","performing","situations","complementary","components","outperforms","combination","engenders","separation","regularization","architectures","clustering","arbitrary","advantage","remarkably","combining","mismatched","independent","significantly","conditions","strengths","separates","embedding","deformation","prominent","artificial","microscope","deformations","registration","classification","variational","validated","operative","furthermore","configuration","intervention","population","individual","downstream","improving","identifies","perturbation","precisely","proposing","covariates","guarantees","relationship","drastically","misspecified","benefici ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	impressively
# 	misspecified
# 	inappropriately
# 	idealized
# 	modulated
# 	sinusoidal
# 	explodingvanishing
# 	cybersecurity
# 	ancestral
# 	sentinels
# 	semiparametric
# 	exemplary
# 	straggler
# 	stragglers
# 	emphasized
# 	sparsifying
# 	sequentialized
# 	simulators
# 	blockwise
# 	ellipsoids
# Some words which never appear in Statistics papers:
# 	microsoft
# 	comprehend
# 	subjectively
# 	backwards
# 	deformations
# 	operative
# 	proactively
# 	egocentric
# 	workspace
# 	compensation
# 	articulated
# 	localizing
# 	superpixel
# 	monocular
# 	uncalibrated
# 	photometric
# 	reflected
# 	shortening
# 	playground
# 	inversely

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.102699348433137e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667
